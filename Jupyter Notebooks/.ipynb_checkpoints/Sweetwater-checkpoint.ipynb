# %%
# import necessary packages
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
# read in JSON
filename = '../JSON/2017-03-14.SWSed.json'
dataSW1 = pd.read_json(filename)
filename2 = '../JSON/2017-03-21.SWSed.json'
dataSW2 = pd.read_json(filename2)

# %%
# Remove Duplicates from data
NoDupsDataSW1 = dataSW1.drop_duplicates()
len(NoDupsDataSW1)

NoDupsDataSW2 = dataSW2.drop_duplicates()
len(NoDupsDataSW2)
# Out:
# 379

# %%
# Concatinate the two cleaned data frames into one data frame
data = pd.concat([NoDupsDataSW1, NoDupsDataSW2])
data = data.drop_duplicates()
data = data.dropna()
len(data)
# Out:
# 417

# %%
# Clean Price Data
data['productPrice'] = data['productPrice'].str.replace('NEGOTIATE','.555')
data['productPrice'] = data['productPrice'].str.replace('Trade','.666')
data['productPrice'] = data['productPrice'].str.replace('SOLD','.777')
data['productPrice'] = data['productPrice'].str.replace('You','.111')
data['productPrice'] = data['productPrice'].str.replace('$','')
data['productPrice'] = data['productPrice'].str.replace('\xa0','')
data['productPrice'] = data['productPrice'].str.replace('.U.S','')
data['productPrice'] = data['productPrice'].str.replace(',','')
data['productPrice'] = data['productPrice'].str.split().str[0]
data['productPrice'] = data['productPrice'].str.split('+').str[0]
data['productPrice'] = data['productPrice'].astype(float)

# %%
# Sort Data by category
Sorted = data.sort_values(['productCategory'], ascending=False)

# Clean Description
data['productDescription'] = data['productDescription'].str.replace('\t\t\t', '')
data['productDescription'] = data['productDescription'].str.replace('\n', '')
data
# Out:
#           productCategory productCondition  \
# 0         Keyboard & MIDI             used
# 1             Microphones              new
# 2          Amps & Effects         like new
# 3         Keyboard & MIDI         like new
# 4           Guitar & Bass             used
# 5                  Mixers         like new
# 6                  Mixers         like new
# 7           Guitar & Bass             used
# 8           Guitar & Bass         like new
# 9                  Mixers         like new
# 10        Keyboard & MIDI             used
# 11      Signal Processing             used
# 12      Signal Processing             used
# 13      Signal Processing             used
# 14                  Other             used
# 15                  Other             used
# 16     Drums & Percussion         like new
# 17      Signal Processing         like new
# 18      Signal Processing         like new
# 19      Signal Processing         like new
# 20         Computer Audio         like new
# 21         Computer Audio         like new
# 22                  Other         like new
# 23        Keyboard & MIDI         like new
# 24                                like new
# 25                                     new
# 26                                    used
# 27      Signal Processing             used
# 28        Keyboard & MIDI             used
# 29                 Mixers         like new
# ..                    ...              ...
# 12                 Mixers             used
# 13                                like new
# 14        Keyboard & MIDI         like new
# 15        Keyboard & MIDI         like new
# 16          Guitar & Bass         like new
# 17         Computer Audio         like new
# 18         Amps & Effects         like new
# 19                                     new
# 20    Speakers & Monitors             used
# 21    Speakers & Monitors             used
# 23          Guitar & Bass         like new
# 24                                    used
# 25            Microphones         like new
# 26            Microphones         like new
# 27            Microphones         like new
# 28            Microphones         like new
# 29          Guitar & Bass         like new
# 30         Amps & Effects         like new
# 31         Amps & Effects              new
# 32         Amps & Effects         like new
# 33         Computer Audio              new
# 34          Guitar & Bass         like new
# 35          Guitar & Bass             used
# 36         Computer Audio             used
# 37      Signal Processing         like new
# 38          Guitar & Bass              new
# 39          Guitar & Bass              new
# 40          Guitar & Bass              new
# 41          Guitar & Bass              new
# 301         Guitar & Bass         like new
#
#                                     productDescription  \
# 0    ASR-10 in excellent condition. Maxed Out at 16...
# 1    Hey guys selling a set of microphones, they ar...
# 2    Like new peavey 6505mh with matched peavey cab...
# 3    Akai mpc 2500 barley used! Good condition work...
# 4    Knaggs Severn Tier 2 for sale, $2200 cash only...
# 5    A like-new behringer MX9000 with power supply....
# 6                   there are 48 inputs and 16 outputs
# 7           2004 Gibson Les Paul Studio metallic black
# 8    Bought this strat 2 months ago I have entirely...
# 9                                      sound board\t\t
# 10   Nice used Modal Electronics 008. Comes with or...
# 11   Very useful in sending one stereo signal out t...
# 12   Adds clarity to recordings or live sound. Hard...
# 13   Design as an 8ch, 8 in and 8out,  single contr...
# 14   I have a couple Scotch 250 and a few 226 empty...
# 15   Mini spot lights with adjustable lens. Max 75w...
# 16   electronic cymbals with sound module can progr...
# 17               Coleman Audio SR5.1MKII Monitor unit.
# 18                     Apogee Big Ben word clock unit.
# 19                     Apogee Big Ben word clock unit.
# 20               Coleman Audio SR5.1MKII Monitor unit.
# 21                     Apogee Big Ben word clock unit.
# 22   LaCie Little Big Disk Thunderbolt 2 - MINT CON...
# 23   I purchased my Roland Integra-7 a little over ...
# 24   Private individual seeking a vintage Garrard 3...
# 25   Brand new. Was bought for a job that never pan...
# 26   Nice Schecter C-1 Classic in transparent blue....
# 27   This is a very rich box. Hundreds of presets, ...
# 28   I'm considering trading my hooked up mpc 1000 ...
# 29          PreSonus StudioLive 32.4.2AI Digital Mixer
# ..                                                 ...
# 12                                     Soundcraft mh3
# 13   I have a Behringer Europower pmp2000 powered, ...
# 14   The A-37 is a "76"key Midi keyboard controller...
# 15   The A-37 is a "76"key Midi keyboard controller...
# 16           I am selling a Taylor T3 Semi Hollow Body
# 17   Mint condition Apollo 8 blackface in box. Purc...
# 18   Like new, only plugged it in twice. Picked it ...
# 19   Screw free guitar strap method. Avoid the dama...
# 20   This is a highly versatile powered speaker / m...
# 21   This is a highly versatile powered speaker / m...
# 23   Like New Condition. Comes with Fender Tweed Ca...
# 24   Private individual seeking a Thorens TD 124 MK...
# 25                          Mic is in mint condition.
# 26   Mic is near mint, used in a handful of VO reco...
# 27   The mic is in near mint condition, mostly been...
# 28   Near mint condition, barely used for a handful...
# 29   This Bass is a Lined Fretless 5-String Solid B...
# 30                                   Nomad 55 FEATURES
# 31   Big Sound, Orange Character, 1 x 12" Convenience!
# 32   The tube amp tone you want without cranking th...
# 33       8 Motorized Faders plus Ample Session Control
# 34   I'm selling a Go-Guitar travel guitar handbuil...
# 35   I've had this guitar for about a year now. It'...
# 36    Not using it much. In smoke Free environment\t\t
# 37   TK Audio TK-LIZER tklizer equalizer Mastering ...
# 38   I'm selling a 2002-2004 fender jazzmaster ambe...
# 39   I'm selling a fender cyclone made in mexico Da...
# 40   I'm selling a eastwood breadwinner comes with ...
# 41   this fender jaguar H H sunburst is made in mex...
# 301  This is a build of less than 197.  I bought th...
#
#                            productID  \
# 0                             119253
# 1                             119252
# 2                             119251
# 3                             119250
# 4                             119249
# 5                             119248
# 6                             119247
# 7                             119246
# 8                             119245
# 9                             119244
# 10                            119243
# 11                            119242
# 12                            119241
# 13                            119240
# 14                            119239
# 15                            119238
# 16                            119237
# 17                            119234
# 18                            119233
# 19                            119233
# 20                            119231
# 21                            119230
# 22                            119217
# 23                            119215
# 24                      $You Tell Me
# 25                              $800
# 26                              $400
# 27                            119211
# 28                            119209
# 29                            119207
# ..                               ...
# 12                            119284
# 13                           $250.00
# 14                            119282
# 15                            119281
# 16                            119280
# 17                            119279
# 18                            119278
# 19                               $40
# 20                            119276
# 21                            119276
# 23                            119273
# 24    $You Let Me Know What You Want
# 25                            119271
# 26                            119270
# 27                            119269
# 28                            119268
# 29                            119266
# 30                            119265
# 31                            119264
# 32                            119263
# 33                            119262
# 34                            119261
# 35                            119260
# 36                            119259
# 37                            119258
# 38                            119257
# 39                            119256
# 40                            119255
# 41                            119254
# 301                           118963
#
#                                            productLink      productLocation  \
# 0    https://tradingpost.sweetwater.com/119253-used...                85143
# 1    https://tradingpost.sweetwater.com/119252-new-...       Millersburg OH
# 2    https://tradingpost.sweetwater.com/119251-like...                26554
# 3    https://tradingpost.sweetwater.com/119250-like...           Roanoke VA
# 4    https://tradingpost.sweetwater.com/119249-used...           Maumee, OH
# 5    https://tradingpost.sweetwater.com/119248-like...                  n/a
# 6    https://tradingpost.sweetwater.com/119247-like...         Madrid,Spain
# 7    https://tradingpost.sweetwater.com/119246-used...           Pomona, CA
# 8    https://tradingpost.sweetwater.com/119245-like...                30165
# 9    https://tradingpost.sweetwater.com/119244-like...            Hutto, TX
# 10   https://tradingpost.sweetwater.com/119243-used...        Greenfield OH
# 11   https://tradingpost.sweetwater.com/119242-used...       Alton NH 03809
# 12   https://tradingpost.sweetwater.com/119241-used...       Alton NH 03809
# 13   https://tradingpost.sweetwater.com/119240-used...       Alton NH 03809
# 14   https://tradingpost.sweetwater.com/119239-used...       Alton NH 03908
# 15   https://tradingpost.sweetwater.com/119238-used...       Alton NH 03809
# 16   https://tradingpost.sweetwater.com/119237-like...            las vegas
# 17   https://tradingpost.sweetwater.com/119234-like...      Connecticut, US
# 18   https://tradingpost.sweetwater.com/119233-like...      Connecticut, US
# 19   https://tradingpost.sweetwater.com/119233-like...                  n/a
# 20   https://tradingpost.sweetwater.com/119231-like...      Connecticut, US
# 21   https://tradingpost.sweetwater.com/119230-like...     Connecticut, USA
# 22   https://tradingpost.sweetwater.com/119217-like...                32301
# 23   https://tradingpost.sweetwater.com/119215-like...          Connecticut
# 24   https://tradingpost.sweetwater.com/119214-like...                  n/a
# 25   https://tradingpost.sweetwater.com/119213-new-...                  n/a
# 26   https://tradingpost.sweetwater.com/119212-used...                  n/a
# 27   https://tradingpost.sweetwater.com/119211-used...                21403
# 28   https://tradingpost.sweetwater.com/119209-used...           Boston, ma
# 29   https://tradingpost.sweetwater.com/119207-like...        New York City
# ..                                                 ...                  ...
# 12   https://tradingpost.sweetwater.com/119284-used...                  n/a
# 13   https://tradingpost.sweetwater.com/119283-like...                  n/a
# 14   https://tradingpost.sweetwater.com/119282-like...             New York
# 15   https://tradingpost.sweetwater.com/119281-like...             New York
# 16   https://tradingpost.sweetwater.com/119280-like...          Cadiz, Ohio
# 17   https://tradingpost.sweetwater.com/119279-like...                  NYC
# 18   https://tradingpost.sweetwater.com/119278-like...             Erie, PA
# 19   https://tradingpost.sweetwater.com/119277-new-...                  n/a
# 20   https://tradingpost.sweetwater.com/119276-used...          LaPorte, IN
# 21   https://tradingpost.sweetwater.com/119276-used...                  n/a
# 23   https://tradingpost.sweetwater.com/119273-like...  Southern New Jersey
# 24   https://tradingpost.sweetwater.com/119272-used...                  n/a
# 25   https://tradingpost.sweetwater.com/119271-like...      Los Angeles, CA
# 26   https://tradingpost.sweetwater.com/119270-like...      Los Angeles, CA
# 27   https://tradingpost.sweetwater.com/119269-like...      Los Angeles, CA
# 28   https://tradingpost.sweetwater.com/119268-like...      Los Angeles, CA
# 29   https://tradingpost.sweetwater.com/119266-like...   Salt Lake City, UT
# 30   https://tradingpost.sweetwater.com/119265-like...          Redmond, OR
# 31   https://tradingpost.sweetwater.com/119264-new-...           Redmond,OR
# 32   https://tradingpost.sweetwater.com/119263-like...          Redmond, OR
# 33   https://tradingpost.sweetwater.com/119262-new-...          Redmond, OR
# 34   https://tradingpost.sweetwater.com/119261-like...         Pasadena, TX
# 35   https://tradingpost.sweetwater.com/119260-used...       Walkertown, NC
# 36   https://tradingpost.sweetwater.com/119259-used...         Kennesaw, ga
# 37   https://tradingpost.sweetwater.com/119258-like...             NEW YORK
# 38   https://tradingpost.sweetwater.com/119257-new-...       plattsburgh ny
# 39   https://tradingpost.sweetwater.com/119256-new-...       plattsburgh ny
# 40   https://tradingpost.sweetwater.com/119255-new-...       plattsburgh ny
# 41   https://tradingpost.sweetwater.com/119254-new-...       plattsburgh ny
# 301  https://tradingpost.sweetwater.com/118963-like...                46628
#
#      productPrice                                       productTitle
# 0         900.000                                     ensoniq asr 10
# 1         400.000           applied microphone technology amt wi5iiv
# 2         550.000                peavey 6505mh with matched 1x12 cab
# 3         625.000                                      akai mpc 2500
# 4        2200.000                               knaggs severn tier 2
# 5         500.000                                   behringer mx9000
# 6        7500.000                                 m audio digico sd8
# 7         700.000                 gibson 2004 gibson les paul studio
# 8         750.000   fender fender jimi hendrix stratocaster w gigbag
# 9         125.000                         alesis multimix 8 firewire
# 10       3400.000                              modal electronics 008
# 11        150.000                         rane sm 26 signal splitter
# 12        150.000                         aphex aural exciter type b
# 13        125.000                          symetrix 488 dyna squeeze
# 14         25.000                              scotch 12 empty reels
# 15        200.000                           mini spot lights unknown
# 16        450.000                                    zildjian gen 16
# 17        450.000                             coleman audio sr51mkii
# 18        475.000                          apogee big ben word clock
# 19        475.000                          apogee big ben word clock
# 20        450.000                             coleman audio sr51mkii
# 21        475.000                                     apogee big ben
# 22        750.000                                      lacie 9000477
# 23       1000.000                                   roland integra 7
# 24          0.111  wanted  gararrd 301turntable 301 transcription...
# 25        800.000                                    avid artist mix
# 26        400.000              schecter c 1 classic transparent blue
# 27        150.000                    roger linn design adrenalinn ii
# 28          0.666                                      akai mpc 1000
# 29       1400.000                         presonus studiolive 3242ai
# ..            ...                                                ...
# 12       2295.000                                soundcraft mh3 mh 3
# 13        250.000                       behringer europower pmp 2000
# 14        340.000      roland a 37  76 key midi keyboard controller
# 15        340.000      roland a 37  76 key midi keyboard controller
# 16       1500.000                         taylor t3 semi hollow body
# 17       1299.000           universal audio apollo 8 duo thunderbolt
# 18         70.000                                    dunlop cry baby
# 19         40.000                   setti setti guitar harness strap
# 20        230.000                                    behringer kxd12
# 21        230.000                                    behringer kxd12
# 23       1095.000           fender stratocaster eric clapton blackie
# 24          0.111                                      thorens td124
# 25        375.000             cascade fathead ii   ribbon microphone
# 26       1800.000  blue kiwi   multi pattern large diaphragm cond...
# 27       1800.000              rode classic ii black tube microphone
# 28        850.000  blue blue blueberry   vocals large diaphragm c...
# 29       1600.000                                      carvin lb75 a
# 30        700.000                     mesa  boogie nomad fifty  five
# 31        300.000                              orange orange ppc 112
# 32        360.000                                 rivera rockcrusher
# 33        380.000                               presonus faderport 8
# 34        450.000                             go guitar go go custom
# 35        320.000                                     epiphone lp100
# 36        300.000             native instruments maschine mk1 studio
# 37       1300.000  tkaudio tk audio tk lizer tklizer equalizer ma...
# 38       1000.000                                  fender jazzmaster
# 39        800.000                                     fender cyclone
# 40        850.000                               eastwood breadwinner
# 41        750.000                                      fender jaguar
# 301      5000.000  paul reed smith brushstroke 24 handsigned by paul
#
# [417 rows x 8 columns]

# %%
# Questions to explore in data
# Guitar brands - Which brand is most available on market? 
#                 Which brand is considered most valuable?
#                 Mean, Median, Mode Prices for each brand

# Which state provides the most listings?

#

# %%
set(data.productCategory)
# Out:
# {' ',
#  ' Amps & Effects',
#  ' Computer Audio',
#  ' Drums & Percussion',
#  ' Guitar & Bass',
#  ' Keyboard & MIDI',
#  ' Microphones',
#  ' Mixers',
#  ' Other',
#  ' Recorders & Players',
#  ' Signal Processing',
#  ' Speakers & Monitors'}

# %%
# DF of all fender guitars
fenders = data['productTitle'].str.contains('fender')
guitar = data['productCategory'] == ' Guitar & Bass'
fenderDF = data[fenders & guitar]
fenderDF

# get mean, median, max, and min on price of fenderDF
fenderMean = fenderDF['productPrice'].mean()
fenderMedian = fenderDF['productPrice'].median()
fenderMax = fenderDF['productPrice'].max()
fenderMin = fenderDF['productPrice'].min()

expensiveFender = data['productPrice'] == fenderMax
expensiveFender = data[fenders & expensiveFender & guitar]

fenderMin,fenderMax,fenderMedian,fenderMean
# Out:
#     productCategory productCondition  \
# 320   Guitar & Bass             used
#
#                                     productDescription productID  \
# 320  Great looking, playing and sounding 1965 all o...    118879
#
#                                            productLink productLocation  \
# 320  https://tradingpost.sweetwater.com/118879-used...   Hollywood, FL
#
#      productPrice              productTitle
# 320       15995.0  fender 1965 stratocaster

# %%
# DF of all Gibson guitars
gibsons = data['productTitle'].str.contains('gibson')
guitar = data['productCategory'] == ' Guitar & Bass'
gibsonDF = data[gibsons & guitar]
gibsonDF

# get mean, median, max, and min on price of gibsonDF
gibsonMean = gibsonDF['productPrice'].mean()
gibsonMedian = gibsonDF['productPrice'].median()
gibsonMax = gibsonDF['productPrice'].max()
gibsonMin = gibsonDF['productPrice'].min()

expensiveGibson = data['productPrice'] == gibsonMax
expensiveGibson = data[gibsons & expensiveGibson & guitar]

cheapestGibson = data['productPrice'] == gibsonMin
cheapestGibson = data[gibsons&cheapestGibson&guitar]

gibsonMin,gibsonMax,gibsonMedian,gibsonMean
# Out:
# (  productCategory productCondition  \
#  0   Guitar & Bass             used
#
#                                    productDescription productID  \
#  0  1974 Les Paul Custom 20th anniversary black be...    119296
#
#                                           productLink productLocation  \
#  0  https://tradingpost.sweetwater.com/119296-used...           95967
#
#     productPrice                                       productTitle
#  0        6650.0  gibson les paul custom 20th anniversary black ...  ,
#      productCategory productCondition  \
#  174   Guitar & Bass             used
#
#                                      productDescription productID  \
#  174  2016 Gibson SG Faded with 490R/490T pickups. G...    119081
#
#                                             productLink productLocation  \
#  174  https://tradingpost.sweetwater.com/119081-used...     Waco, Texas
#
#       productPrice     productTitle
#  174         535.0  gibson sg faded  )

# %%
# DF of all Epiphone Guitars
epiphones = data['productTitle'].str.contains('epiphone')
guitar = data['productCategory'] == ' Guitar & Bass'
epiphoneDF = data[epiphones & guitar]
epiphoneDF

# get mean, median, max, and min on price of epiphoneDF
epiphoneMean = epiphoneDF['productPrice'].mean()
epiphoneMedian = epiphoneDF['productPrice'].median()
epiphoneMax = epiphoneDF['productPrice'].max()
epiphoneMin = epiphoneDF['productPrice'].min()

# Determine most expensive and cheapest
expensiveEpiphone = data['productPrice'] == epiphoneMax
expensiveEpiphone = data[epiphones & expensiveEpiphone & guitar]
cheapestEpiphone = data['productPrice'] == epiphoneMin
cheapestEpiphone = data[epiphones&cheapestEpiphone&guitar]

epiphoneMin,epiphoneMax,epiphoneMedian,epiphoneMean
# Out:
# (320.0, 900.0, 400.0, 540.0)

# %%
# DF of all Ibanez Guitars
ibanez = data['productTitle'].str.contains('ibanez')
guitar = data['productCategory'] == ' Guitar & Bass'
ibanezDF = data[ibanez & guitar]
ibanezDF

# get mean, median, max, and min on price of ibanezDF
ibanezMean = ibanezDF['productPrice'].mean()
ibanezMedian = ibanezDF['productPrice'].median()
ibanezMax = ibanezDF['productPrice'].max()
ibanezMin = ibanezDF['productPrice'].min()

# Determine most expensive and cheapest
expensiveIbanez = data['productPrice'] == ibanezMax
expensiveIbanez = data[ibanez & expensiveIbanez & guitar]
cheapestIbanez = data['productPrice'] == epiphoneMin
cheapestIbanez = data[ibanez&cheapestIbanez&guitar]

ibanezMin,ibanezMax,ibanezMedian,ibanezMean
# Out:
# (269.0, 300.0, 297.5, 291.0)

# %%
# DF of all Microphones
mic = data['productCategory'] == ' Microphones'
microphonesDF = data[mic]

micMean = microphonesDF['productPrice'].mean()
micMedian = microphonesDF['productPrice'].median()
micMax = microphonesDF['productPrice'].max()
micMin = microphonesDF['productPrice'].min()

micMin, micMax, micMedian, micMean
# Out:
# (65.0, 5999.0, 625.0, 974.66666666666663)

# %%
# Find Most expensive and Cheapest Microphone
mic = data['productCategory'] == ' Microphones'

mostExpensiveMic = data['productPrice'] == micMax
mostExpensiveMic = data[mostExpensiveMic & mic]

cheapestMic = data['productPrice'] == micMin
cheapestMic = data[cheapestMic & mic]


mostExpensiveMic
# Out:
#     productCategory productCondition productDescription productID  \
# 234     Microphones         like new   THE KING OF MICS    119000
#
#                                            productLink productLocation  \
# 234  https://tradingpost.sweetwater.com/119000-like...     Slidell, LA
#
#      productPrice productTitle
# 234        5999.0  sony c 800g

# %%
 # Data to plot
labels = 'Fender', 'Gibson', 'Epiphone', 'Ibanez'
sizes = [len(fenderDF), len(gibsonDF), len(epiphoneDF), len(ibanezDF)]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0, 0.1, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %%
# list most expensive and cheapest products
