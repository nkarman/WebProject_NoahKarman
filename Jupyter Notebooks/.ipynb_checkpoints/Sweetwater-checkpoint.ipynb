# %%
# import necessary packages
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
# read in JSON
filename = '2017-03-14.SWSed.json'
dataSW1 = pd.read_json(filename)
filename2 = '2017-03-21.SWSed.json'
dataSW2 = pd.read_json(filename2)

# %%
# Remove Duplicates from data
NoDupsDataSW1 = dataSW1.drop_duplicates()
len(NoDupsDataSW1)

NoDupsDataSW2 = dataSW2.drop_duplicates()
len(NoDupsDataSW2)
# Out:
# 379

# %%
# Concatinate the two cleaned data frames into one data frame
data = pd.concat([NoDupsDataSW1, NoDupsDataSW2])
len(data)
# Out:
# 754

# %%
# Clean Price Data
data['productPrice'] = data['productPrice'].str.replace('NEGOTIATE','.555')
data['productPrice'] = data['productPrice'].str.replace('Trade','.666')
data['productPrice'] = data['productPrice'].str.replace('SOLD','.777')
data['productPrice'] = data['productPrice'].str.replace('You','.111')
data['productPrice'] = data['productPrice'].str.replace('$','')
data['productPrice'] = data['productPrice'].str.replace('\xa0','')
data['productPrice'] = data['productPrice'].str.replace('.U.S','')
data['productPrice'] = data['productPrice'].str.replace(',','')
data['productPrice'] = data['productPrice'].str.split().str[0]
data['productPrice'] = data['productPrice'].str.split('+').str[0]
data['productPrice'] = data['productPrice'].astype(float)

# %%
# Sort Data by category
Sorted = data.sort_values(['productCategory'], ascending=False)

# Clean Description
data['productDescription'] = data['productDescription'].str.replace('\t\t\t', '')
data['productDescription'] = data['productDescription'].str.replace('\n', '')
data
# Out:
#           productCategory productCondition  \
# 0         Keyboard & MIDI             used
# 1             Microphones              new
# 2          Amps & Effects         like new
# 3         Keyboard & MIDI         like new
# 4           Guitar & Bass             used
# 5                  Mixers         like new
# 6                  Mixers         like new
# 7           Guitar & Bass             used
# 8           Guitar & Bass         like new
# 9                  Mixers         like new
# 10        Keyboard & MIDI             used
# 11      Signal Processing             used
# 12      Signal Processing             used
# 13      Signal Processing             used
# 14                  Other             used
# 15                  Other             used
# 16     Drums & Percussion         like new
# 17      Signal Processing         like new
# 18      Signal Processing         like new
# 19      Signal Processing         like new
# 20         Computer Audio         like new
# 21         Computer Audio         like new
# 22                  Other         like new
# 23        Keyboard & MIDI         like new
# 24                                like new
# 25                                     new
# 26                                    used
# 27      Signal Processing             used
# 28        Keyboard & MIDI             used
# 29                 Mixers         like new
# ..                    ...              ...
# 407     Signal Processing             used
# 408     Signal Processing         like new
# 409         Guitar & Bass             used
# 410         Guitar & Bass             used
# 411         Guitar & Bass         like new
# 412         Guitar & Bass         like new
# 413         Guitar & Bass         like new
# 414        Amps & Effects         like new
# 415       Keyboard & MIDI         like new
# 416                Mixers             used
# 418        Computer Audio         like new
# 419                Mixers             used
# 420     Signal Processing         like new
# 421        Computer Audio         like new
# 422       Keyboard & MIDI             used
# 423         Guitar & Bass             used
# 424   Speakers & Monitors             used
# 425   Speakers & Monitors             used
# 426       Keyboard & MIDI             used
# 427       Keyboard & MIDI         like new
# 428                Mixers         like new
# 429   Recorders & Players             used
# 430   Recorders & Players             used
# 431       Keyboard & MIDI              new
# 432       Keyboard & MIDI              new
# 433                Mixers             used
# 434                Mixers             used
# 435                Mixers             used
# 437   Speakers & Monitors         like new
# 438    Drums & Percussion         like new
#
#                                     productDescription      productID  \
# 0    ASR-10 in excellent condition. Maxed Out at 16...         119253
# 1    Hey guys selling a set of microphones, they ar...         119252
# 2    Like new peavey 6505mh with matched peavey cab...         119251
# 3    Akai mpc 2500 barley used! Good condition work...         119250
# 4    Knaggs Severn Tier 2 for sale, $2200 cash only...         119249
# 5    A like-new behringer MX9000 with power supply....         119248
# 6                   there are 48 inputs and 16 outputs         119247
# 7           2004 Gibson Les Paul Studio metallic black         119246
# 8    Bought this strat 2 months ago I have entirely...         119245
# 9                                      sound board\t\t         119244
# 10   Nice used Modal Electronics 008. Comes with or...         119243
# 11   Very useful in sending one stereo signal out t...         119242
# 12   Adds clarity to recordings or live sound. Hard...         119241
# 13   Design as an 8ch, 8 in and 8out,  single contr...         119240
# 14   I have a couple Scotch 250 and a few 226 empty...         119239
# 15   Mini spot lights with adjustable lens. Max 75w...         119238
# 16   electronic cymbals with sound module can progr...         119237
# 17               Coleman Audio SR5.1MKII Monitor unit.         119234
# 18                     Apogee Big Ben word clock unit.         119233
# 19                     Apogee Big Ben word clock unit.         119233
# 20               Coleman Audio SR5.1MKII Monitor unit.         119231
# 21                     Apogee Big Ben word clock unit.         119230
# 22   LaCie Little Big Disk Thunderbolt 2 - MINT CON...         119217
# 23   I purchased my Roland Integra-7 a little over ...         119215
# 24   Private individual seeking a vintage Garrard 3...   $You Tell Me
# 25   Brand new. Was bought for a job that never pan...           $800
# 26   Nice Schecter C-1 Classic in transparent blue....           $400
# 27   This is a very rich box. Hundreds of presets, ...         119211
# 28   I'm considering trading my hooked up mpc 1000 ...         119209
# 29          PreSonus StudioLive 32.4.2AI Digital Mixer         119207
# ..                                                 ...            ...
# 407  Cry Baby Guitar Wah effect by Dunlop. Used. $4...         118814
# 408  Like New  Banshee Talk Box by Rocktron. assort...         118813
# 409  1994 Custom 22 PRS. Cherry Red. Set Neck. Seri...         118812
# 410  1994 Custom 22 PRS. Cherry Red. Set Neck. Seri...         118812
# 411  I realize it seems too good to be true, but I ...         118807
# 412  I realize it seems too good to be true, but I ...         118806
# 413  I realize it seems too good to be true, but I ...         118805
# 414  For sale my 2016 Bogner 2x12 closed back cab. ...         118804
# 415                                     PRICE REDUCED!         118803
# 416  24 Channel Mixer Board comes with a travelling...         118802
# 418  This M-Audio Fast Track Ultra is in excellent ...         118800
# 419  For sale is an AVID Venue SC48 with the follow...         118799
# 420                      Condition of Item and Parts:          118798
# 421  CPU efficient buss compressor and channel stri...         118794
# 422                                  This item is rare         118793
# 423  Nice Gibson SG Standard Cherry, early 70's gui...         118792
# 424  3 way powered speaker pair. Great set of speak...         118791
# 425  3 way powered speaker pair. Great set of speak...         118790
# 426  Selling this Yamaha M08 Workstation Keyboard i...         118788
# 427  Selling this Yamaha S90XS Workstation Keyboard...         118787
# 428  This Mixer is Like New. I installed it in a Hi...         118786
# 429  Clean unit, used sparingly, original box and m...         118785
# 430  Clean unit, used sparingly, original box and m...         118785
# 431  Still in box never been used. Comes with compr...         118783
# 432  Still in box never been used. Comes with compr...         118782
# 433  In perfect working order. Has scratches on sid...         118781
# 422  https://tradingpost.sweetwater.com/118793-used...                  n/a
# 423  https://tradingpost.sweetwater.com/118792-used...  Huntertown, Indiana
# 424  https://tradingpost.sweetwater.com/118791-used...       Nashville, Tn.
# 425  https://tradingpost.sweetwater.com/118790-used...       Nashville, Tn.
# 426  https://tradingpost.sweetwater.com/118788-used...      Cooper City, FL
# 427  https://tradingpost.sweetwater.com/118787-like...      Cooper City, FL
# 428  https://tradingpost.sweetwater.com/118786-like...             Vicco Ky
# 429  https://tradingpost.sweetwater.com/118785-used...      Yugawara, JAPAN
# 430  https://tradingpost.sweetwater.com/118785-used...                  n/a
# 431  https://tradingpost.sweetwater.com/118783-new-...           Alpine, CA
# 432  https://tradingpost.sweetwater.com/118782-new-...           Alpine, CA
# 433  https://tradingpost.sweetwater.com/118781-used...           Alpine, CA
# 434  https://tradingpost.sweetwater.com/118780-used...           Alpine, CA
# 435  https://tradingpost.sweetwater.com/118780-used...                  n/a
# 437  https://tradingpost.sweetwater.com/118773-like...           Seattle WA
# 438  https://tradingpost.sweetwater.com/118769-like...          Chicago, IL
#
#      productPrice                                       productTitle
# 0         900.000                                     ensoniq asr 10
# 1         400.000           applied microphone technology amt wi5iiv
# 2         550.000                peavey 6505mh with matched 1x12 cab
# 3         625.000                                      akai mpc 2500
# 4        2200.000                               knaggs severn tier 2
# 5         500.000                                   behringer mx9000
# 6        7500.000                                 m audio digico sd8
# 7         700.000                 gibson 2004 gibson les paul studio
# 8         750.000   fender fender jimi hendrix stratocaster w gigbag
# 9         125.000                         alesis multimix 8 firewire
# 10       3400.000                              modal electronics 008
# 11        150.000                         rane sm 26 signal splitter
# 12        150.000                         aphex aural exciter type b
# 13        125.000                          symetrix 488 dyna squeeze
# 14         25.000                              scotch 12 empty reels
# 15        200.000                           mini spot lights unknown
# 16        450.000                                    zildjian gen 16
# 17        450.000                             coleman audio sr51mkii
# 18        475.000                          apogee big ben word clock
# 19        475.000                          apogee big ben word clock
# 20        450.000                             coleman audio sr51mkii
# 21        475.000                                     apogee big ben
# 22        750.000                                      lacie 9000477
# 23       1000.000                                   roland integra 7
# 24          0.111  wanted  gararrd 301turntable 301 transcription...
# 25        800.000                                    avid artist mix
# 26        400.000              schecter c 1 classic transparent blue
# 27        150.000                    roger linn design adrenalinn ii
# 28          0.666                                      akai mpc 1000
# 29       1400.000                         presonus studiolive 3242ai
# ..            ...                                                ...
# 407        40.000                         dunlop cry baby guitar wah
# 408       100.000                          rocktron banshee talk box
# 409      1300.000                          paul reed smith custom 22
# 410      1300.000                          paul reed smith custom 22
# 411       175.000  premium guitar fret replacement service refret...
# 412       175.000  premium guitar fret replacement service refret...
# 413       175.000  premium guitar re fret services refret optiona...
# 414       675.000                     bogner bogner 2x12 closed back
# 415      4500.000              yamaha tyros5 76 keyboard synthesizer
# 416       499.000                           allen &amp; heath gl2200
# 418       200.000                           m audio fast track ultra
# 419     17500.000                                          avid sc48
# 420       400.000               sound devices mm 1 microphone preamp
# 421       250.000                       ssl duende native essentials
# 422       370.000                           roland vocal processor 7
# 423      2300.000                                 gibson sg standard
# 424      1800.000                                       qsc hpr 123i
# 425      1800.000                                       qsc hpr 123i
# 426       799.000                                         yamaha mo8
# 427      1699.000                                       yamaha s90xs
# 428       750.000                      allen heath gl 2400 gl2400 32
# 429      1795.000                                  sound devices 702
# 430      1795.000                                  sound devices 702
# 431       350.000                         novation abelton launchpad
# 432       350.000                         novation abelton launchpad
# 433      1900.000                          allen &amp; heath zed 436
# 434       500.000                                    mackie profx 22
# 435       500.000                                    mackie profx 22
# 437      1800.000                              electro voice etx 35p
# 438      1200.000                                     roland td 25kv
#
# [754 rows x 8 columns]

# %%
# Questions to explore in data
# Guitar brands - Which brand is most available on market? 
#                 Which brand is considered most valuable?
#                 Mean, Median, Mode Prices for each brand

# Which state provides the most listings?

#

# %%
set(data.productCategory)
# Out:
# {' ',
#  ' Amps & Effects',
#  ' Computer Audio',
#  ' Drums & Percussion',
#  ' Guitar & Bass',
#  ' Keyboard & MIDI',
#  ' Microphones',
#  ' Mixers',
#  ' Other',
#  ' Recorders & Players',
#  ' Signal Processing',
#  ' Speakers & Monitors'}

# %%
# DF of all fender guitars
fenders = data['productTitle'].str.contains('fender')
guitar = data['productCategory'] == ' Guitar & Bass'
fenderDF = data[fenders & guitar]
fenderDF

# DF of all Gibson guitars
gibsons = data['productTitle'].str.contains('gibson')
guitar = data['productCategory'] == ' Guitar & Bass'
gibsonDF = data[gibsons & guitar]
gibsonDF

# DF of all Epiphone Guitars
epiphones = data['productTitle'].str.contains('epiphone')
guitar = data['productCategory'] == ' Guitar & Bass'
epiphoneDF = data[epiphones & guitar]
epiphoneDF

# DF of all Ibanez Guitars
ibanez = data['productTitle'].str.contains('ibanez')
guitar = data['productCategory'] == ' Guitar & Bass'
ibanezDF = data[ibanez & guitar]
ibanezDF
# Out:
#     productCategory productCondition  \
# 129   Guitar & Bass         like new
# 282   Guitar & Bass             used
# 423   Guitar & Bass         like new
# 424   Guitar & Bass         like new
# 168   Guitar & Bass         like new
# 317   Guitar & Bass             used
#
#                                     productDescription productID  \
# 129                          Ibanez sr300m bass!  like    119146
# 282  Excellent condition With NEW HARDSHELL Case ($...    118925
# 423  Very Beautiful looking and sounding. Exotic Ze...    118744
# 424  Very Beautiful looking and sounding. Exotic Ze...    118743
# 168                          Ibanez sr300m bass!  like    119146
# 317  Excellent condition With NEW HARDSHELL Case ($...    118925
#
#                                            productLink     productLocation  \
# 129  https://tradingpost.sweetwater.com/119146-like...      palm coast, fl
# 282  https://tradingpost.sweetwater.com/118925-used...               85718
# 423  https://tradingpost.sweetwater.com/118744-like...  84047 Midvale Utah
# 424  https://tradingpost.sweetwater.com/118743-like...  84047 Midvale Utah
# 168  https://tradingpost.sweetwater.com/119146-like...      palm coast, fl
# 317  https://tradingpost.sweetwater.com/118925-used...               85718
#
#      productPrice                                       productTitle
# 129         295.0                                ibanez sr300m  bass
# 282         269.0  ibanez aeg10n nylon string w case and electronics
# 423         300.0                             ibanez ew20zw nt 14 01
# 424         300.0                             ibanez ew20zw nt 14 01
# 168         295.0                                ibanez sr300m  bass
# 317         269.0  ibanez aeg10n nylon string w case and electronics
