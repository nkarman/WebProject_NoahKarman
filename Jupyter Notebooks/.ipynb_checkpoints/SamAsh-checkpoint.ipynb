# %%
# import necessary packages
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
# read in JSON
filename = '../JSON/2017-03-21.SA_used.json'
dataSA1 = pd.read_json(filename)
filename2 = '../JSON/2017-04-18.SA_used.json'
dataSA2 = pd.read_json(filename2)

# %%
# Remove Duplicates from data
NoDupsDataSA1 = dataSA1.drop_duplicates()
len(NoDupsDataSA1)

NoDupsDataSA2 = dataSA2.drop_duplicates()
len(NoDupsDataSA2)
# Out:
# 3690

# %%
# Concatinate the two cleaned data frames into one data frame
data = pd.concat([NoDupsDataSA1, NoDupsDataSA2])
data = data.drop_duplicates()
data = data.dropna()
data.reset_index()
len(data)
# Out:
# 4658

# %%
# clean price data strings and convert to float

data['productPrice'] = data['productPrice'].str.replace('NEGOTIATE','.555')
data['productPrice'] = data['productPrice'].str.replace('Trade','.666')
data['productPrice'] = data['productPrice'].str.replace('SOLD','.777')
data['productPrice'] = data['productPrice'].str.replace('You','.111')
data['productPrice'] = data['productPrice'].str.replace('$','')
data['productPrice'] = data['productPrice'].str.replace('\xa0','')
data['productPrice'] = data['productPrice'].str.replace('.U.S','')
data['productPrice'] = data['productPrice'].str.replace(',','')
data['productPrice'] = data['productPrice'].str.replace('n/a','')
data['productPrice'] = data['productPrice'].str.replace('<a','')
data['productPrice'] = data['productPrice'].str.replace('First','')
data['productPrice'] = data['productPrice'].str.replace('<span','')
data['productPrice'] = data['productPrice'].str.replace('href="item.php?id=84685"><img','')
data['productPrice'] = data['productPrice'].str.split().str[0]
data['productPrice'] = data['productPrice'].str.split('+').str[0]
data['productPrice'] = data['productPrice'].astype(float)

# %%
# Sort Data by category
Sorted = data.sort_values(['productCategory'], ascending=False)

# Clean Description
data['productDescription'] = data['productDescription'].str.replace('\t\t\t', '')
data['productDescription'] = data['productDescription'].str.replace('\n', '')
data
# Out:
#      productCategory productCondition  \
# 0      Guitar & Bass              n/a
# 1      Guitar & Bass              n/a
# 2      Guitar & Bass              n/a
# 3      Guitar & Bass              n/a
# 4      Guitar & Bass              n/a
# 5      Guitar & Bass              n/a
# 6      Guitar & Bass              n/a
# 7      Guitar & Bass              n/a
# 8      Guitar & Bass              n/a
# 9      Guitar & Bass              n/a
# 10     Guitar & Bass              n/a
# 11     Guitar & Bass              n/a
# 12     Guitar & Bass              n/a
# 13     Guitar & Bass              n/a
# 14     Guitar & Bass              n/a
# 15     Guitar & Bass              n/a
# 16     Guitar & Bass              n/a
# 17     Guitar & Bass              n/a
# 18     Guitar & Bass              n/a
# 19     Guitar & Bass              n/a
# 20     Guitar & Bass              n/a
# 21     Guitar & Bass              n/a
# 22     Guitar & Bass              n/a
# 23     Guitar & Bass              n/a
# 24     Guitar & Bass              n/a
# 25     Guitar & Bass              n/a
# 26     Guitar & Bass              n/a
# 27     Guitar & Bass              n/a
# 28     Guitar & Bass              n/a
# 29     Guitar & Bass              n/a
# ...              ...              ...
# 3123  Amps & Effects              n/a
# 3124  Amps & Effects              n/a
# 3125  Amps & Effects              n/a
# 3126  Amps & Effects              n/a
# 3127  Amps & Effects              n/a
# 3128  Amps & Effects              n/a
# 3129  Amps & Effects              n/a
# 3130  Amps & Effects              n/a
# 3131  Amps & Effects              n/a
# 3132  Amps & Effects              n/a
# 3133  Amps & Effects              n/a
# 3135  Amps & Effects              n/a
# 3136  Amps & Effects              n/a
# 3137  Amps & Effects              n/a
# 3138  Amps & Effects              n/a
# 3139  Amps & Effects              n/a
# 3140  Amps & Effects              n/a
# 3141  Amps & Effects              n/a
# 3142  Amps & Effects              n/a
# 3143  Amps & Effects              n/a
# 3144  Amps & Effects              n/a
# 3145  Amps & Effects              n/a
# 3146  Amps & Effects              n/a
# 3148  Amps & Effects              n/a
# 3149  Amps & Effects              n/a
# 3150  Amps & Effects              n/a
# 3156  Amps & Effects              n/a
# 3189  Amps & Effects              n/a
# 3260  Amps & Effects              n/a
# 3502  Amps & Effects              n/a
#
#                                      productDescription  productID  \
# 0     This is the 2009 Godin Velocity in fantastic c...      93785
# 1     This is the 2009 Godin Velocity in fantastic c...      93784
# 2     This is an Epiphone Les Paul Standard electric...      93773
# 3     This limited edition 2013 408 (only 50 pieces ...      93682
# 4     Here is a beautiful Gibson Custom Shop 1959 Co...      93660
# 5       This is the Mike Mushok Signature guitar , M...      93684
# 6     This S2 Standard is in fantastic shape. No rea...      93695
# 7     This is the Buzz Feiten Blues Pro Deluxe "T" S...      93673
# 8     This Ibanez RG7421PB 7 string guitar is in dec...      93692
# 9      The Jackson ICJ Electric Guitar , a hot rod m...      93744
# 10    Beautiful 2002 D'Angelico made in Japan by Ves...      93665
# 11    This USA made G&L Legacy stratocaster style gu...      93686
# 12    Here we have an American Telecaster Special in...      93758
# 13    Looking for a truly stunning affordable guitar...      93754
# 14                       Great looking and playing PRS!      93735
# 15    This is one monster of a guitar. It plays and ...      93723
# 16                        Great playing lefty Les Paul!      93721
# 17    Authentic Les Paul tones and looks, versatile ...      93749
# 18    This modern classic is in excellent shape. If ...      93740
# 19    This is the 2000 Fender Mexican Standard Strat...      93677
# 20    Tons of bang for you buck.  The Quality on Epi...      93626
# 21    This beautiful Japanese made ESP M-III feature...      93600
# 22    The Ibanez DT250 Destroy is made for the 80's ...      93611
# 23    Here we have a Epiphone Les Paul Florentine. P...      93624
# 24    This killer ESP Mirage features an all red pai...      93604
# 25    Great condition. Top is in great shape, back h...      93651
# 26    The BC Rich Virgin guitar features dual Dimarz...      93601
# 27    This guitar is in great condition. It has a sm...      93635
# 28    Epiphone Casino Gary Clark LTD.  2 Gibson USA ...      93577
# 29    Here we have a 2011 Fano TC6 guitar. This rare...      93620
# ...                                                 ...        ...
# 3123  This is an Oddfellow Bishop Overdrive pedal. I...      94312
# 3124  Here we have an AD9 analog delay. It is in goo...      94310
# 3125  This Fuzz Face Mini Distortion sounds bright a...      94306
# 3126  This is the G system by TC electronics. This p...      94281
# 3127  Blackstar LT Distortion in Almost new conditio...      94207
# 3128          Radial PB1 Big Shot Class A Power Booster      94206
# 3129  The Boss Power Stack Distortion is a high gain...      94265
# 3130            Solid Gold FX Zeta High Gain Superdrive      94193
# 3131  Classic English fuzz with a taste of tube, The...      94260
# 3132  The constrictor is a simple compressor with a ...      94250
# 3133  This is a Wiggler Vibrato Tremolo pedal. It fe...      94253
# 3135  This is a powerful reverb with plenty of optio...      94230
# 3136  Ok so today we have a TC Electronic Arena Reve...      94209
# 3137  This pedal is in great condition with almost n...      94147
# 3138             DigiTech Crossroads Eric Clapton Pedal      94163
# 3139  Great older distortion pedal in good condition...      94124
# 3140    This Fulltone Fat Boost FB-3 is in great sha...      94075
# 3141  This TC Electronic Shaker pedal is in great co...      93953
# 3142  This Boss BF-3 Flanger pedal is in great condi...      93951
# 3143  A two-faced overdrive with endless settings. T...      93965
# 3144  The Akai Professional Deluxe Distortion Guitar...      94013
# 3145  This is a Pigtronix Philosopher Bass Compresso...      93863
# 3146    This Keeley Fuzz Head fuzz pedal is in near ...      93876
# 3148  When it comes to distortion pedals there are m...      93901
# 3149  The Pork Loin is a great overdrive pedal with ...      93840
# 3150  Do you want the tone of the Irish fuzz!  Look ...      93835
# 3156  This is the Echolution2 by Pigtronix. This del...      93649
# 3189                          The Disnotion is awesome!      93213
# 3260                                               None      92275
# 3502  This pedal is in good shape with only a few sc...      80991
#
#                                         productLink       productLocation  \
# 0     http://used.samashmusic.com/item.php?id=93785         San Diego, CA
# 1     http://used.samashmusic.com/item.php?id=93784         San Diego, CA
# 2     http://used.samashmusic.com/item.php?id=93773         Charlotte, NC
# 3     http://used.samashmusic.com/item.php?id=93682      Cherry Hill , NJ
# 4     http://used.samashmusic.com/item.php?id=93660           Madison, TN
# 5     http://used.samashmusic.com/item.php?id=93684       San Antonio, TX
# 6     http://used.samashmusic.com/item.php?id=93695      Cherry Hill , NJ
# 7     http://used.samashmusic.com/item.php?id=93673         San Diego, CA
# 8     http://used.samashmusic.com/item.php?id=93692         New Haven, CT
# 9     http://used.samashmusic.com/item.php?id=93744       San Antonio, TX
# 10    http://used.samashmusic.com/item.php?id=93665           Madison, TN
# 11    http://used.samashmusic.com/item.php?id=93686         New Haven, CT
# 12    http://used.samashmusic.com/item.php?id=93758           Ontario, CA
# 13    http://used.samashmusic.com/item.php?id=93754       Carle Place, NY
# 14    http://used.samashmusic.com/item.php?id=93735  King Of Prussia , PA
# 15    http://used.samashmusic.com/item.php?id=93723       Canoga Park, CA
# 16    http://used.samashmusic.com/item.php?id=93721  King Of Prussia , PA
# 17    http://used.samashmusic.com/item.php?id=93749       Canoga Park, CA
# 18    http://used.samashmusic.com/item.php?id=93740       Canoga Park, CA
# 19    http://used.samashmusic.com/item.php?id=93677         San Diego, CA
# 20    http://used.samashmusic.com/item.php?id=93626          Torrance, CA
# 21    http://used.samashmusic.com/item.php?id=93600          Glendale, AZ
# 22    http://used.samashmusic.com/item.php?id=93611          Glendale, AZ
# 23    http://used.samashmusic.com/item.php?id=93624           Ontario, CA
# 24    http://used.samashmusic.com/item.php?id=93604          Glendale, AZ
# 25    http://used.samashmusic.com/item.php?id=93651       Westminster, CA
# 26    http://used.samashmusic.com/item.php?id=93601          Glendale, AZ
# 27    http://used.samashmusic.com/item.php?id=93635           Lombard, IL
# 28    http://used.samashmusic.com/item.php?id=93577     Buffalo Grove, IL
# 29    http://used.samashmusic.com/item.php?id=93620           Ontario, CA
# ...                                             ...                   ...
# 3123  http://used.samashmusic.com/item.php?id=94312      Forest Hills, NY
# 3124  http://used.samashmusic.com/item.php?id=94310      Forest Hills, NY
# 3125  http://used.samashmusic.com/item.php?id=94306  City Of Industry, CA
# 3126  http://used.samashmusic.com/item.php?id=94281            Tampa , FL
# 3127  http://used.samashmusic.com/item.php?id=94207       Miami Lakes, FL
# 3128  http://used.samashmusic.com/item.php?id=94206            Edison, NJ
# 3129  http://used.samashmusic.com/item.php?id=94265            Tampa , FL
# 3130  http://used.samashmusic.com/item.php?id=94193     Buffalo Grove, IL
# 3131  http://used.samashmusic.com/item.php?id=94260            Tampa , FL
# 3132  http://used.samashmusic.com/item.php?id=94250            Tampa , FL
# 3133  http://used.samashmusic.com/item.php?id=94253            Tampa , FL
# 3135  http://used.samashmusic.com/item.php?id=94230            Tampa , FL
# 3136  http://used.samashmusic.com/item.php?id=94209       Carle Place, NY
# 3137  http://used.samashmusic.com/item.php?id=94147             Miami, FL
# 3138  http://used.samashmusic.com/item.php?id=94163     Buffalo Grove, IL
# 3139  http://used.samashmusic.com/item.php?id=94124           Raleigh, NC
# 3140  http://used.samashmusic.com/item.php?id=94075       Springfield, NJ
# 3141  http://used.samashmusic.com/item.php?id=93953         New Haven, CT
# 3142  http://used.samashmusic.com/item.php?id=93951         New Haven, CT
# 3143  http://used.samashmusic.com/item.php?id=93965           Orlando, FL
# 3144  http://used.samashmusic.com/item.php?id=94013        Clearwater, FL
# 3145  http://used.samashmusic.com/item.php?id=93863         Charlotte, NC
# 3146  http://used.samashmusic.com/item.php?id=93876       Springfield, NJ
# 3148  http://used.samashmusic.com/item.php?id=93901      Indianapolis, IN
# 3149  http://used.samashmusic.com/item.php?id=93840          New York, NY
# 3150  http://used.samashmusic.com/item.php?id=93835          New York, NY
# 3156  http://used.samashmusic.com/item.php?id=93649           Ontario, CA
# 3189  http://used.samashmusic.com/item.php?id=93213            Dallas, TX
# 3260                                            n/a                   n/a
# 3502  http://used.samashmusic.com/item.php?id=80991           Raleigh, NC
#
#       productPrice                                       productTitle
# 0           429.99                                     Godin Velocity
# 1           379.99                                     Godin Velocity
# 2           299.99                         Epiphone Les Paul Standard
# 3          2499.99        Paul Reed Smith Ltd Edition 408 Semi-Hollow
# 4          5999.99                      Gibson Les Paul CC#30 'Gabby"
# 5           499.99              Paul Reed Smith Mike Mushok Signature
# 6           899.99                     Paul Reed Smith S2 24 STANDARD
# 7           999.99                                   Feiten Blues Pro
# 8           199.99                                    Ibanez RG7421PB
# 9           649.99                                Jackson JACKSON ICJ
# 10         1899.99                          NYSD-9 w/ Case MIJ Vestax
# 11          899.99                                         G&L Legacy
# 12          749.99                            Fender American Special
# 13          439.99  Paul Reed Smith Paul Reed Smith SE "Floyd" Cus...
# 14          419.99                   Paul Reed Smith PRS SE Custom 24
# 15          549.99                                       Dean USA "Z"
# 16          379.99         Epiphone Les Paul Standard Pro Left-Handed
# 17         1199.99                                   Gibson Less Plus
# 18         1399.99                                       Fender Elite
# 19          399.99                              Fender Standard Strat
# 20          399.99                              Epiphone Plus Top Pro
# 21         1449.99                                          ESP M-III
# 22          349.99                                       Ibanez DT250
# 23          479.99                                Epiphone Florentine
# 24          999.99                                         ESP Mirage
# 25          349.99                 Epiphone Les Paul Standard Goldtop
# 26          799.99                                     BC Rich Virgin
# 27         1199.99                         Music Man Axis Super Sport
# 28          749.00                                    Epiphone Casino
# 29         1899.99                                           Fano TC6
# ...            ...                                                ...
# 3123        119.99                     ODDfELLOW THE BISHOP OVERDRIVE
# 3124         99.99                            Ibanez AD9 ANALOG DELAY
# 3125         69.99                                        Dunlop FFM1
# 3126        999.99                             TC Electronic G Ststem
# 3127         29.99                            BlackStar LT Distortion
# 3128         99.99                                         Radial PB1
# 3129         69.99                              Boss Power Stack ST-2
# 3130        119.99                                 Solid Gold FX Zeta
# 3131        139.99                      Electro Harmonix English Muff
# 3132         65.00                                  Line6 Constrictor
# 3133        175.00                           Electro Harmonix Wiggler
# 3135        174.99                     TC Electronic NR-1 NOVA Reverb
# 3136         90.00                         TC Electronic Arena Reverb
# 3137        249.99                            Moog Moogerfooger MF103
# 3138         59.99                                DigiTech Crossroads
# 3139         59.99                                        Ibanez PDS1
# 3140         79.99                                      Fulltone FB-3
# 3141         79.99                               TC Electronic Shaker
# 3142         79.99                                  Boss BF-3 Flanger
# 3143         79.99                               Fulltone Fulldrive 2
# 3144         89.99                             Akai Deluxe Distortion
# 3145        119.99                              Pigtronix Philosopher
# 3146        119.99                       Keeley Electronics Fuzz Head
# 3148        149.99          Wampler Sovereign Distortion Effect Pedal
# 3149        114.99          Way Huge Pork Loin Guitar Overdrive Pedal
# 3150         99.99   Custom Danny Boy Shamrock Amps Guitar Fuzz Pedal
# 3156        199.00                              Pigtronix Echolution2
# 3189        249.99                               Pigtronix Distortion
# 3260           NaN                       Pigtronix Philosopher's Tone
# 3502         69.99                            Pigtronix POLYSATURATOR
#
# [4658 rows x 8 columns]

# %%
# Questions to explore in data
# Guitar brands - Which brand is most available on market? 
#                 Which brand is considered most valuable?
#                 Mean, Median, Mode Prices for each brand

# Which state provides the most listings?

#

# %%
set(data.productCategory)
# Out:
# {'Amps & Effects',
#  'Drums & Percussion',
#  'Guitar & Bass',
#  'Keyboard & MIDI',
#  'Microphones',
#  'Mixers'}

# %%
# DF of all fender guitars
fenders = data['productTitle'].str.contains('Fender')
guitar = data['productCategory'] == 'Guitar & Bass'
fenderDF = data[guitar & fenders]

fenderDF

# get Mean, Median, max, min other data
fenderMean = fenderDF['productPrice'].mean()
fenderMed = fenderDF['productPrice'].median()
fenderMax = fenderDF['productPrice'].max()
fenderMin = fenderDF['productPrice'].min()

expensiveFender = data['productPrice'] == fenderMax
expensiveFender = data[fenders & expensiveFender & guitar]

cheapestFender = data['productPrice'] == fenderMin
cheapestFender = data[fenders & cheapestFender & guitar]

# %%
# DF of all Gibson guitars
gibsons = data['productTitle'].str.contains('Gibson')
guitar = data['productCategory'] == 'Guitar & Bass'
gibsonDF = data[gibsons & guitar]

# get mean, median, max, and min on price of gibsonDF
gibsonMean = gibsonDF['productPrice'].mean()
gibsonMedian = gibsonDF['productPrice'].median()
gibsonMax = gibsonDF['productPrice'].max()
gibsonMin = gibsonDF['productPrice'].min()

# Determine most expensive and cheapest
expensiveGibson = data['productPrice'] == gibsonMax
expensiveGibson = data[gibsons & expensiveGibson & guitar]

cheapestGibson = data['productPrice'] == gibsonMin
cheapestGibson = data[gibsons&cheapestGibson&guitar]

gibsonMin,gibsonMax,gibsonMedian,gibsonMean
# Out:
# (429.99000000000001, 9999.9899999999998, 1299.0, 1641.8972804532577)

# %%
# DF of all Epiphone Guitars
epiphones = data['productTitle'].str.contains('Epiphone')
guitar = data['productCategory'] == 'Guitar & Bass'
epiphoneDF = data[epiphones & guitar]

# get mean, median, max, and min on price of epiphoneDF
epiphoneMean = epiphoneDF['productPrice'].mean()
epiphoneMedian = epiphoneDF['productPrice'].median()
epiphoneMax = epiphoneDF['productPrice'].max()
epiphoneMin = epiphoneDF['productPrice'].min()

# Determine most expensive and cheapest
expensiveEpiphone = data['productPrice'] == epiphoneMax
expensiveEpiphone = data[epiphones & expensiveEpiphone & guitar]

cheapestEpiphone = data['productPrice'] == epiphoneMin
cheapestEpiphone = data[epiphones&cheapestEpiphone&guitar]

epiphoneMin,epiphoneMax,epiphoneMedian,epiphoneMean
# Out:
# (129.0, 4799.9899999999998, 449.0, 481.03811023622029)

# %%
# DF of all Ibanez Guitars
ibanez = data['productTitle'].str.contains('Ibanez')
guitar = data['productCategory'] == 'Guitar & Bass'
ibanezDF = data[ibanez & guitar]

# get mean, median, max, and min on price of ibanezDF
ibanezMean = ibanezDF['productPrice'].mean()
ibanezMedian = ibanezDF['productPrice'].median()
ibanezMax = ibanezDF['productPrice'].max()
ibanezMin = ibanezDF['productPrice'].min()

# Determine most expensive and cheapest
expensiveIbanez = data['productPrice'] == ibanezMax
expensiveIbanez = data[ibanez & expensiveIbanez & guitar]
cheapestIbanez = data['productPrice'] == epiphoneMin
cheapestIbanez = data[ibanez&cheapestIbanez&guitar]

ibanezMin,ibanezMax,ibanezMedian,ibanezMean
# Out:
# (79.989999999999995, 2299.9899999999998, 499.99, 601.77276595744661)

# %%
# DF of all Microphones
mic = data['productCategory'] == 'Microphones'
microphonesDF = data[mic]

micMean = microphonesDF['productPrice'].mean()
micMedian = microphonesDF['productPrice'].median()
micMax = microphonesDF['productPrice'].max()
micMin = microphonesDF['productPrice'].min()

micMin, micMax, micMedian, micMean
# Out:
# (14.99, 10999.99, 129.99, 317.12485294117647)

# %%
# Find Most expensive and Cheapest Microphone
mic = data['productCategory'] == 'Microphones'

mostExpensiveMic = data['productPrice'] == micMax
mostExpensiveMic = data[mostExpensiveMic & mic]

cheapestMic = data['productPrice'] == micMin
cheapestMic = data[cheapestMic & mic]


cheapestMic
# Out:
#      productCategory productCondition           productDescription  productID  \
# 2475     Microphones              n/a  Fair condition, light wear.      96759
#
#                                         productLink productLocation  \
# 2475  http://used.samashmusic.com/item.php?id=96759   New Haven, CT
#
#       productPrice productTitle
# 2475         14.99    CAD SA-70

# %%
# Data to plot
labels = 'Fender', 'Gibson', 'Epiphone', 'Ibanez'
sizes = [len(fenderDF), len(gibsonDF), len(epiphoneDF), len(ibanezDF)]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0, 0.1, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %%
# list most expensive and cheapest products
