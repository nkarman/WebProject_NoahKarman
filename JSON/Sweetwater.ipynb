# %%
# import necessary packages
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
# read in JSON
filename = '2017-03-14.SWSed.json'
dataSW1 = pd.read_json(filename)
filename2 = '2017-03-16.SWSed.json'
dataSW2 = pd.read_json(filename2)

# %%
# Data Cleaning

# Remove Duplicates from data
NoDupsDataSW1 = dataSW1.drop_duplicates()
len(NoDupsDataSW1)

NoDupsDataSW2 = dataSW2.drop_duplicates()
len(NoDupsDataSW2)
# Out:
# 376

# %%
# Create Inner Merge to determine 
dataInnerMerge = pd.merge(NoDupsDataSW1, NoDupsDataSW2, \
                          on=['productID','productLocation','productTitle','productPrice'],\
                          how='inner')

# %%
# Determine the set of 'new products'
NoDupsDataSW2['key1'] = 1
dataInnerMerge['key2'] = 1
newProducts = pd.merge(NoDupsDataSW2, dataInnerMerge, \
                      on=['productID', 'productTitle','productLocation','productPrice'], \
                      how = 'left')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
# Out:
# 375

# %%
len(dataSA1)
# Out:
# 3522

# %%
NoDupsDataSA1 = dataSA1.drop_duplicates()
len(NoDupsDataSA1)
# Out:
# 3502

# %%
#Create a dataframe containing the intersection of the two.
dataAppended = NoDupsDataSA1.append(NoDupsDataSW1)
len(dataAppended)
# Out:
# 3877

# %%
Sorted = dataAppended.sort_values(['productCategory'], ascending=False)
Sorted
# Out:
#       productCategory productCondition  \
# 2723           Mixers              NaN
# 2732           Mixers              NaN
# 2722           Mixers              NaN
# 2724           Mixers              NaN
# 2725           Mixers              NaN
# 2726           Mixers              NaN
# 2727           Mixers              NaN
# 2728           Mixers              NaN
# 2730           Mixers              NaN
# 2731           Mixers              NaN
# 2729           Mixers              NaN
# 2733           Mixers              NaN
# 2735           Mixers              NaN
# 2736           Mixers              NaN
# 2737           Mixers              NaN
# 2738           Mixers              NaN
# 2739           Mixers              NaN
# 2740           Mixers              NaN
# 2734           Mixers              NaN
# 2741           Mixers              NaN
# 2614      Microphones              NaN
# 2611      Microphones              NaN
# 2612      Microphones              NaN
# 2613      Microphones              NaN
# 2617      Microphones              NaN
# 2615      Microphones              NaN
# 2616      Microphones              NaN
# 2609      Microphones              NaN
# 2610      Microphones              NaN
# 2720      Microphones              NaN
# ...               ...              ...
# 162    Amps & Effects             used
# 161    Amps & Effects             used
# 25                                 new
# 136                           like new
# 106                               used
# 197                           like new
# 31                            like new
# 37                            like new
# 260                               used
# 40                            like new
# 32                            like new
# 349                           like new
# 33                            like new
# 34                            like new
# 341                           like new
# 35                            like new
# 26                                used
# 309                                new
# 308                                new
# 307                                new
# 306                                new
# 305                                new
# 304                                new
# 303                                new
# 302                                new
# 36                            like new
# 38                            like new
# 39                            like new
# 405                           like new
# 24                            like new
#
#                                      productDescription  \
# 2723  Tascam Portastudio 424 MKIII tape recorder. 6 ...
# 2732  This is a full featured mixer with XLR inputs ...
# 2722             The FLM 82 Line Mixer consists of four
# 2724                                               None
# 2725   Soundcraft Vi4 offers access to 96 inputs on ...
# 2726  16 Channel Analog mixer in good conditon with ...
# 2727  32 channels of analog goodness. This is a fant...
# 2728  The mixer that started the digital mixer revol...
# 2730               SCUFF ON THE SIDE----GREAT CONDITION
# 2731  There are 6 balanced mono inputs and outputs c...
# 2729  The Line 6 M20D is a 20-ch Digital Mixer with ...
# 2733  The ultra-compact Mix Series is the answer for...
# 2735  The Samson TXM20 is a 20 channel powered mixer...
# 2736                                               None
# 2737  This 24-input model is suitable for serious li...
# 2738  The LX7ii continues in the tradition of the hi...
# 2739  We have an amazing Presonus 24.4.2 AI Digital ...
# 2740  This N8 digital mixer has FireWire connectivit...
# 2734  This QX1222 mixer is in great condition in and...
# 2741  14 Channel Live Sound Mixer with Built in EFX ...
# 2614  Good condition, some aesthetic scratches. Come...
# 2611  Includes shock mount. Cables not included. Thi...
# 2612  This package includes a C01 condenser mic and ...
# 2613  Very good condition MXL R144 ribbon microphone...
# 2617  Here's a great sounding studio mic. The Trion ...
# 2615  This mic is great for inputing a signal analog...
# 2616  This dynamic microphone made by Sony is a repl...
# 2609                                                n/a
# 2610  This Sennheiser MK4 is a large diaphragm conde...
# 2720  A great in-store closeout buy! The Barcus Berr...
# ...                                                 ...
# 162   \n\t\t\tNever used live and barely used in hom...
# 161   \n\t\t\tNever used live and barely used in hom...
# 25    \n\t\t\tBrand new. Was bought for a job that n...
# 136   \n\t\t\tThis is a hardly used Roland VS-700C, ...
# 106   \n\t\t\tI'm looking for a nice Thorens TD-124 ...
# 197   \n\t\t\tI have a like new apollo twin duo usb ...
# 31    \n\t\t\tPRESETS:  50.                         ...
# 37    \n\t\t\tFor sale is Verity Audio Parsifal Ovat...
# 260   \n\t\t\tMartin second generation thinline 332 ...
# 40    \n\t\t\tThe acclaimed E-300 series has a stron...
# 32    \n\t\t\tMcIntosh MC2000 50th anniversary amp, ...
# 349   \n\t\t\tThis pedal is like new. Only used twic...
# 33    \n\t\t\tFor sale is a pair of Nagra VP 845 Mon...
# 34                              \n\t\t\tSpecifications:
# 341   \n\t\t\tThe synth works as perfect as the day ...
# 35    \n\t\t\tLamm ML1 monoblock power amplifiers fo...
# 26    \n\t\t\tNice Schecter C-1 Classic in transpare...
# 309   \n\t\t\tThis is a license transfer. After purc...
# 308   \n\t\t\tThis is a license transfer. I will pay...
# 307   \n\t\t\tThis is a license transfer. After the ...
# 306   \n\t\t\tThis is a license transfer. After buye...
# 305   \n\t\t\tThis is a license transfer. After the ...
# 304   \n\t\t\tThis is a license transfer. After the ...
# 303   \n\t\t\tThis is a license transfer. After the ...
# 302   \n\t\t\tThis is a license transfer. After the ...
# 36                              \n\t\t\tSpecifications:
# 38    \n\t\t\tMcIntosh MC205 5-ch amplifier. The uni...
# 39    \n\t\t\tThe acclaimed E-300 series has a stron...
# 405   \n\t\t\t2016 Rickenbacker 4003 Jetglo black-li...
# 24    \n\t\t\tPrivate individual seeking a vintage G...
#
#                   productID  \
# 2723                  92932
# 2732                  92236
# 2722                  92964
# 2724                  92887
# 2725                  92882
# 2726                  92686
# 2727                  92577
# 2728                  92567
# 2730                  92215
# 2731                  92239
# 2729                  92297
# 2733                  92238
# 2735                  91824
# 2736                  91557
# 2737                  91419
# 2738                  91411
# 2739                  91454
# 2740                  90803
# 2734                  91769
# 2741                  90719
# 2614                  89542
# 2611                  89762
# 2612                  89741
# 2613                  89704
# 2617                  89094
# 2615                  89325
# 2616                  89237
# 2609                  89934
# 2610                  89869
# 2720                  47669
# ...                     ...
# 162                  119097
# 161                  119098
# 25                     $800
# 136    $1,395 or best offer
# 106            $You Tell Me
# 197                    $500
# 31                  $540.00
# 37                    $4600
# 260                  $50.00
# 40                    $3400
# 32                    $4600
# 349                    $130
# 33                    $5200
# 34                    $4990
# 341                    $320
# 35                    $2900
# 26                     $400
# 309                 $210.00
# 308                 $250.00
# 307                 $175.00
# 306                  $70.00
# 305                     $70
# 304                  $70.00
# 303                  $70.00
# 302                  $70.00
# 36                    $3550
# 38                    $2900
# 39                    $3400
# 405                $1595.00
# 24             $You Tell Me
#
#                                             productLink       productLocation  \
# 2723      http://used.samashmusic.com/item.php?id=92932        Cincinnati, OH
# 2732      http://used.samashmusic.com/item.php?id=92236          Richmond, VA
# 2722      http://used.samashmusic.com/item.php?id=92964           Atlanta, GA
# 2724      http://used.samashmusic.com/item.php?id=92887           Atlanta, GA
# 2725      http://used.samashmusic.com/item.php?id=92882           Atlanta, GA
# 2726      http://used.samashmusic.com/item.php?id=92686           Paramus, NJ
# 2727      http://used.samashmusic.com/item.php?id=92577           Raleigh, NC
# 2728      http://used.samashmusic.com/item.php?id=92567           Raleigh, NC
# 2730      http://used.samashmusic.com/item.php?id=92215  King Of Prussia , PA
# 2731      http://used.samashmusic.com/item.php?id=92239          Richmond, VA
# 2729      http://used.samashmusic.com/item.php?id=92297          Glendale, AZ
# 2733      http://used.samashmusic.com/item.php?id=92238          Richmond, VA
# 2735      http://used.samashmusic.com/item.php?id=91824       Carle Place, NY
# 2736      http://used.samashmusic.com/item.php?id=91557           Atlanta, GA
# 2737      http://used.samashmusic.com/item.php?id=91419          Richmond, VA
# 2738      http://used.samashmusic.com/item.php?id=91411          Richmond, VA
# 2739      http://used.samashmusic.com/item.php?id=91454        Cincinnati, OH
# 2740      http://used.samashmusic.com/item.php?id=90803       San Antonio, TX
# 2734      http://used.samashmusic.com/item.php?id=91769       San Antonio, TX
# 2741      http://used.samashmusic.com/item.php?id=90719           Paramus, NJ
# 2614      http://used.samashmusic.com/item.php?id=89542         Hollywood, CA
# 2611      http://used.samashmusic.com/item.php?id=89762      Philadelphia, PA
# 2612      http://used.samashmusic.com/item.php?id=89741           Paramus, NJ
# 2613      http://used.samashmusic.com/item.php?id=89704        Clearwater, FL
# 2617      http://used.samashmusic.com/item.php?id=89094       San Antonio, TX
# 2615      http://used.samashmusic.com/item.php?id=89325        Cincinnati, OH
# 2616      http://used.samashmusic.com/item.php?id=89237      Indianapolis, IN
# 2609                                                n/a                   n/a
# 2610      http://used.samashmusic.com/item.php?id=89869      Forest Hills, NY
# 2720      http://used.samashmusic.com/item.php?id=47669       San Antonio, TX
# ...                                                 ...                   ...
# 162   https://tradingpost.sweetwater.com/119097-used...         Hollywood, CA
# 161   https://tradingpost.sweetwater.com/119098-used...         Hollywood, CA
# 25    https://tradingpost.sweetwater.com/119213-new-...                   n/a
# 136   https://tradingpost.sweetwater.com/119132-like...                   n/a
# 106   https://tradingpost.sweetwater.com/119172-used...                   n/a
# 197   https://tradingpost.sweetwater.com/119055-like...                   n/a
# 31    https://tradingpost.sweetwater.com/119205-like...                   n/a
# 37    https://tradingpost.sweetwater.com/119195-like...                   n/a
# 260   https://tradingpost.sweetwater.com/118971-used...                   n/a
# 40    https://tradingpost.sweetwater.com/119193-like...                    \n
# 32    https://tradingpost.sweetwater.com/119200-like...                   n/a
# 349   https://tradingpost.sweetwater.com/118843-like...                   n/a
# 33    https://tradingpost.sweetwater.com/119199-like...                   n/a
# 34    https://tradingpost.sweetwater.com/119198-like...                   n/a
# 341   https://tradingpost.sweetwater.com/118856-like...                   n/a
# 35    https://tradingpost.sweetwater.com/119197-like...                   n/a
# 26    https://tradingpost.sweetwater.com/119212-used...                   n/a
# 309   https://tradingpost.sweetwater.com/118893-new-...                   n/a
# 308   https://tradingpost.sweetwater.com/118894-new-...                   n/a
# 307   https://tradingpost.sweetwater.com/118895-new-...                   n/a
# 306   https://tradingpost.sweetwater.com/118896-new-...                   n/a
# 305   https://tradingpost.sweetwater.com/118897-new-...                   n/a
# 304   https://tradingpost.sweetwater.com/118898-new-...                   n/a
# 303   https://tradingpost.sweetwater.com/118899-new-...                   n/a
# 302   https://tradingpost.sweetwater.com/118900-new-...                   n/a
# 36    https://tradingpost.sweetwater.com/119196-like...                   n/a
# 38    https://tradingpost.sweetwater.com/119194-like...                   n/a
# 39    https://tradingpost.sweetwater.com/119193-like...                   n/a
# 405   https://tradingpost.sweetwater.com/118768-like...                   n/a
# 24    https://tradingpost.sweetwater.com/119214-like...                   n/a
#
#                productPrice                                       productTitle
# 2723                 $19.99                       Tascam Portastudio 424 MKIII
# 2732                $199.99                                Electro-Voice BK832
# 2722                $119.99                                        Rane FLM-82
# 2724              $1,799.99                                   Midas Venice 320
# 2725             $17,999.99                                     Soundcraft VI4
# 2726                $249.99                                      Mackie SR1604
# 2727                $799.99                              Allen&Heath GL2400 32
# 2728                $699.99                         Presonus StudioLive 16.4.2
# 2730                $399.99                                    Mackie PPM 1008
# 2731                 $59.99                                         Rane SM26B
# 2729                $829.99                                         Line6 M20D
# 2733                 $39.99                                        Tapco Mix60
# 2735                $498.77                                       Samson TXM20
# 2736                $239.99                                      Yamaha MG12XU
# 2737                $499.99                                   Yamaha MG24/14FX
# 2738                $599.99                                 Soundcraft LXII-24
# 2739              $1,499.95                                 Presonus 24.4.2 AI
# 2740                $399.99                                          Yamaha N8
# 2734                $149.99                         Behringer QX1222 Xenyx USB
# 2741                $349.99                                    Yorkville VGM14
# 2614                $169.99                   OKTAVA - MC 012-01 Condenser Mic
# 2611                $849.99                                           AKG C414
# 2612                 $69.99                                    Samson C01 Pack
# 2613                 $74.99                                           MXL R144
# 2617                $329.99                                CAD TRION 8000 Tube
# 2615                 $34.99                             IK Multimedia iRig Mic
# 2616                 $19.99                       Sony Sony Dynamic Microphone
# 2609                    n/a                                               None
# 2610                $219.77                                     Sennheiser MK4
# 2720                $166.65                           Barcus Berry Piezo 3000A
# ...                     ...                                                ...
# 162                   $500                         fender blues deluxe reissue
# 161                   $300                       line 6 spider valve mk ii 212
# 25                    $800                                     avid artist mix
# 136   $1,395 or best offer             roland vs 700 digital audio workstation
# 106            You Tell Me                                  wtb: thorens td124
# 197                   $500                         uni uad apollo twin duo usb
# 31                 $540.00         novation super bass station   synth module
# 37                   $4600                       verity audio parsifal ovation
# 260                 $50.00                                       martin 24ctsg
# 40                   $3400                                     accuphase e 350
# 32                   $4600                                     mcintosh mc2000
# 349                   $130                              aguilar tlc compressor
# 33                   $5200         nagra vpa 845 tube class a triode monoblock
# 34                   $4990                         pass labs xa1005 mono block
# 341                   $320                    korg arp odyssey duophonic synth
# 35                   $2900                 lamm ml1 monoblock power amplifiers
# 26                    $400               schecter c 1 classic transparent blue
# 309                $210.00         presonus studio one 3 professional download
# 308                $250.00     ik multimedia sampletank 3 workstation download
# 307                $175.00               native instruments battery 4 download
# 306                 $70.00            native instruments alecias keyz download
# 305                    $70                native instruments solid eq download
# 304                 $70.00    native instruments solid bus compressor download
# 303                 $70.00   native instruments solid dynamics compressor d...
# 302                 $70.00                native instruments drum lab download
# 36                   $3550                             chord cpm 3300 flagship
# 38                   $2900                           mcintosh mc 205 5 channel
# 39                   $3400                                     accuphase e 350
# 405               $1595.00                                   rickenbacker 4003
# 24             You Tell Me   wanted  gararrd 301turntable 301 transcription...
#
# [3877 rows x 8 columns]

# %%
NoDupsData['key1'] = 1
dataInnerMerge['key2'] = 1
dataInnerMerge.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a4930c63a886> in <module>()
# ----> 1 NoDupsData['key1'] = 1
#       2 dataInnerMerge['key2'] = 1
#       3 dataInnerMerge.head()
#
# NameError: name 'NoDupsData' is not defined

# %%
closedProducts = pd.merge(NoDupsData, dataInnerMerge, \
                      on=['ID', 'Title','Location','Price'], \
                      how = 'left')
closedProducts

# %%
closedProducts = closedProducts[~(closedProducts.key2 == closedProducts.key1)]
closedProducts

# %%
NoDupsData2['key1'] = 1
newProducts = pd.merge(NoDupsData2, dataInnerMerge, \
                      on=['ID', 'Title','Location','Price'], \
                      how = 'left')
newProducts = newProducts[~(newProducts.key2 == newProducts.key1)]
newProducts = newProducts.drop(['key1','key2'], axis=1)
len(newProducts)

# %%
newProducts

# %%
set(data.Location)
# Decisions to be made
# Some Zips
# Some City, State
# Various outputs

# %%
data['Location'].replace({'2 Monitors and sub': 'Not Included', 
                          'DFW' : 'Dallas - Fortworth, TX',
                          '84047 Midvale Utah' : 'Midvale, Utah 84047',
                          '08085 swedesboro NJ' : 'Swedesboro, NF 08085'
                         }, inplace=True)

# %%
set(data.Location)

# %%
set(data.Price)

# %%
data['Price'] = data['Price'].str.replace('$', '')
data['Price'] = data['Price'].str.replace(',', '')
data['Price'] = data['Price'].str.replace(u'\xa0', u' ')
data['Price'] = data['Price'].str.replace('NEGOTIATE', '.555')
data['Price'] = data['Price'].str.replace('SOLD', '.777')
data['Price'] = data['Price'].str.replace('1000.U.S', '1000')
data['Price'] = data['Price'].str.split().str[0]
data['Price'] = data['Price'].str.split('+').str[0]
data['Price'] = data['Price'].astype(float)
set(data.Price)
